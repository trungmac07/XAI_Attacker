# %%
import numpy as np # to handle matrix and data operation


import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.utils.data
from torch.utils.data import random_split
from torch.utils.data import DataLoader

from torchvision.utils import save_image

from torch.autograd import Variable

from torchvision.datasets import MNIST, CIFAR10
import torchvision.transforms as transforms
import torchvision

import PIL.Image as Image
import io
import matplotlib.pyplot as plt

import shutil

# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#shutil.copyfile("/content/drive/MyDrive/animals_cnn_model/animals-resnet34-29.pth", "./animals-resnet34-29.pth")

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
class SpearmanCorrelation(nn.Module):
    def __init__(self):
        super(SpearmanCorrelation, self).__init__()

    def forward(self, x, y):
        x = torch.flatten(x)
        y = torch.flatten(y)
        x_mean = torch.mean(x)
        y_mean = torch.mean(y)
        x_std = torch.std(x)
        y_std = torch.std(y)
        x = (x - x_mean) / x_std
        y = (y - y_mean) / y_std
        rho = torch.sum(x * y) / (torch.sqrt(torch.sum(x ** 2)) * torch.sqrt(torch.sum(y ** 2)))
        return rho

# %%
class SimpleGradient:
    def __init__(self, model, img_size=(28,28), device = 'cpu'):
        self.device = device
        self.model = model
        self.img_size = img_size

    def explain(self, x, y, model = None):
        if model is None:
            model = self.model

        img = x

        if(len(img.size()) <= 3):
            img = img.unsqueeze(0)

        y_pred = F.softmax(model.forward(img))

        y_pred = torch.index_select(y_pred,1,y)

        saliency_map = torch.autograd.grad(y_pred, img, create_graph=True)[0]

        saliency_map = torch.sum(saliency_map, dim = 1)


        saliency_map = F.relu(saliency_map)

        min_val = torch.min(saliency_map)
        max_val = torch.max(saliency_map)


        saliency_map = 1/(max_val - min_val) * (saliency_map - min_val)

        return saliency_map

# %%
class IntegratedGradient:
    def __init__(self, model, img_size=(28,28), device = 'cpu'):
        self.device = device
        self.model = model
        self.img_size = img_size


    def explain(self, x, y, model = None, step = 50, baseline = None):

        if(model==None):
            model = self.model
        img = x

        if(len(img.size()) <= 3):
            img = img.unsqueeze(0)

        saliency_map = torch.zeros(img.shape, device=self.device, requires_grad=True)
        if(baseline == None):
            baseline = torch.zeros(img.shape, device=self.device,  requires_grad=True)

        dif = img - baseline

        x_ig = torch.stack([baseline + a/step*dif for a in range(step+1)]).squeeze()
        model.zero_grad()
        y_pred = F.softmax(model.forward(x_ig))
        y_pred = torch.index_select(y_pred,1,y)
        grad = torch.autograd.grad(y_pred, x_ig, create_graph=True, grad_outputs=torch.ones_like(y_pred))[0]
        saliency_map = saliency_map + torch.sum(grad, dim = 0)

        saliency_map = 1.0/(step+1) * saliency_map * dif
        saliency_map = torch.sum(saliency_map, dim = 1)

        saliency_map = F.relu(saliency_map)

        min_val = torch.min(saliency_map)
        max_val = torch.max(saliency_map)


        saliency_map = 1/(max_val - min_val) * (saliency_map - min_val)

        return saliency_map

# %%
class Attacker:

    def __init__(self, img_size = (28,28), device = 'cpu'):

        self.device = device
        self.loss = nn.CosineSimilarity()
        self.img_size = img_size


    def grad_compute(self, x, xp, real_y_pred, model, model_p, explainer, mode = 'random', target = None):


        if(mode == 'random'):
            target = explainer.explain(x,real_y_pred, model = model)

        p_explanation = explainer.explain(xp,real_y_pred, model = model_p)

        if(target == None or mode == 'random'):
            mean1 = torch.mean(target)
            std1 = torch.std(target)
            target = (target - mean1) / std1
            mean2 = torch.mean(p_explanation)
            std2 = torch.std(p_explanation)
            loss = -self.loss(torch.flatten(target.detach()).unsqueeze(0),torch.flatten(p_explanation).unsqueeze(0))

        if(mode == 'target'):
            mean1 = torch.mean(target)
            std1 = torch.std(target)
            target = (target - mean1) / std1
            mean2 = torch.mean(p_explanation)
            std2 = torch.std(p_explanation)
            p_explanation = (p_explanation - mean2) / std2
            loss = self.loss(torch.flatten(target).unsqueeze(0),torch.flatten(p_explanation).unsqueeze(0))

        grad = torch.autograd.grad(loss, xp)[0]

        return grad, loss


    def iterative_attack(self, x, model, model_p = None, explainer = None, alpha = 0.5, epsilon = 0.003, num_steps = 100, mode = 'random', target = None):

        if(model_p == None):
            model_p = model

        x = torchvision.transforms.Resize(self.img_size)(x.clone())
        x.requires_grad_(True)
        if(len(x.shape) <= 3):
            x = x.unsqueeze(0)
        y = torch.argmax(model.forward(x))
        xp = [x]
        losses = [-1e9]
        for i in range(num_steps):

            print(f"Iteration {i} is running")
            grad, loss = self.grad_compute(x,xp[i],y,model,model_p,explainer,mode,target)

            xpi = x + torch.clip(xp[i] + alpha * torch.sign(grad) - x, -epsilon, epsilon)
            xpi = xpi.clip(0, 1)
            xp.append(xpi)
            if(torch.argmax(model.forward(xpi)) == y):
                losses.append(loss)
                print("LOSS:",loss)
            else:
                losses.append(-1e9)
                print("LOSS:",-1e9)



        max_loss = -1e9
        min_i = 0
        for i, l in enumerate(losses):
            if(l > max_loss):
                max_loss = l
                min_i = i
        print("LOSSES:",losses)
        print(min_i)
        print(losses[min_i])


        return xp[min_i]

# %%
animals_dict = {
    0 : "dog",
    1 : "horse",
    2 : "deer",
    3 : "elephant",
    4 : "butterfly",
    5 : "chicken",
    6 : "cat",
    7 : "cow",
    8 : "lamb",
    9 : "squirrel"

}

# %%
path = "squirrel.jpg"
img = Image.open(path)
plt.imshow(img)
X = transforms.ToTensor()(img).to(device).requires_grad_(True)

# %%
# Function to replace ReLU with Softplus
def replace_relu_with_softplus(module):
    for name, child in module.named_children():
        if isinstance(child, nn.ReLU):
            setattr(module, name, nn.Softplus(beta=5))
        else:
            replace_relu_with_softplus(child)

# %%
cnn = torchvision.models.resnet34().to(device)
cnn_p = torchvision.models.resnet34().to(device)

# Apply the function to the model
replace_relu_with_softplus(cnn_p)

num_features = cnn.fc.in_features
cnn.fc = nn.Linear(num_features, 10, device = device)

num_features = cnn_p.fc.in_features
cnn_p.fc = nn.Linear(num_features, 10, device = device)

cnn.load_state_dict(torch.load("./animals-resnet34-29.pth"))
cnn_p.load_state_dict(torch.load("./animals-resnet34-29.pth"))

cnn.eval()
cnn_p.eval()

g = SimpleGradient(cnn, img_size=(224,224), device=device)
ig = IntegratedGradient(cnn, img_size=(224,224), device=device)

attacker = Attacker(img_size=(224,224), device=device)

# %%
target = torch.zeros((1,224,224), device=device)
target[0,150:210,15:150] += 1.0
# target[0,15:90,10:50] += 0.9
# target[0,155:205,155:205] += 0.75

plt.imshow(target.permute([1,2,0]).to('cpu'), cmap='hot')

# %%
X_p_g_1 = attacker.iterative_attack(X, model = cnn, model_p=cnn_p, explainer=g, num_steps = 150, alpha = 0.002, epsilon=0.03, mode = 'target', target = target)
X_p_g_2 = attacker.iterative_attack(X, model = cnn, model_p=cnn_p, explainer=g, num_steps = 150, alpha = 0.002, epsilon=0.03, mode = 'random')
# Out:
# Iteration 0 is running
# <ipython-input-5-acc1a5bc07ab>:16: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_pred = F.softmax(model.forward(img))
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# LOSS: tensor([-0.0371], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 1 is running
# LOSS: tensor([0.0183], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 2 is running
# LOSS: tensor([0.0699], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 3 is running
# LOSS: tensor([0.1225], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 4 is running
# LOSS: tensor([0.1546], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 5 is running
# LOSS: tensor([0.2005], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 6 is running
# LOSS: tensor([0.2222], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 7 is running
# LOSS: tensor([0.2497], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 8 is running
# LOSS: tensor([0.2551], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 9 is running
# LOSS: tensor([0.2826], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 10 is running
# LOSS: tensor([0.3019], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 11 is running
# LOSS: tensor([0.3040], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 12 is running
# LOSS: tensor([0.3159], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 13 is running
# LOSS: tensor([0.3337], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 14 is running
# LOSS: tensor([0.3363], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 15 is running
# LOSS: tensor([0.3536], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 16 is running
# LOSS: tensor([0.3525], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 17 is running
# LOSS: tensor([0.3661], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 18 is running
# LOSS: tensor([0.3637], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 19 is running
# LOSS: tensor([0.3810], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 20 is running
# LOSS: tensor([0.3751], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 21 is running
# LOSS: tensor([0.3866], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 22 is running
# LOSS: tensor([0.3835], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 23 is running
# LOSS: tensor([0.3941], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 24 is running
# LOSS: tensor([0.3928], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 25 is running
# LOSS: tensor([0.4004], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 26 is running
# LOSS: tensor([0.3967], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 27 is running
# LOSS: tensor([0.4089], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 28 is running
# LOSS: tensor([0.4073], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 29 is running
# LOSS: tensor([0.4095], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 30 is running
# LOSS: tensor([0.4105], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 31 is running
# LOSS: tensor([0.4153], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 32 is running
# LOSS: tensor([0.4140], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 33 is running
# LOSS: tensor([0.4192], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 34 is running
# LOSS: tensor([0.4187], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 35 is running
# LOSS: tensor([0.4239], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 36 is running
# LOSS: tensor([0.4214], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 37 is running
# LOSS: tensor([0.4254], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 38 is running
# LOSS: tensor([0.4230], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 39 is running
# LOSS: tensor([0.4295], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 40 is running
# LOSS: tensor([0.4259], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 41 is running
# LOSS: tensor([0.4314], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 42 is running
# LOSS: tensor([0.4273], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 43 is running
# LOSS: tensor([0.4317], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 44 is running
# LOSS: tensor([0.4289], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 45 is running
# LOSS: tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 46 is running
# LOSS: tensor([0.4321], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 47 is running
# LOSS: tensor([0.4369], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 48 is running
# LOSS: tensor([0.4325], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 49 is running
# LOSS: tensor([0.4359], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 50 is running
# LOSS: tensor([0.4334], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 51 is running
# LOSS: tensor([0.4398], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 52 is running
# LOSS: tensor([0.4351], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 53 is running
# LOSS: tensor([0.4397], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 54 is running
# LOSS: tensor([0.4376], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 55 is running
# LOSS: tensor([0.4402], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 56 is running
# LOSS: tensor([0.4375], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 57 is running
# LOSS: tensor([0.4419], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 58 is running
# LOSS: tensor([0.4380], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 59 is running
# LOSS: tensor([0.4424], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 60 is running
# LOSS: tensor([0.4396], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 61 is running
# LOSS: tensor([0.4429], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 62 is running
# LOSS: tensor([0.4379], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 63 is running
# LOSS: tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 64 is running
# LOSS: tensor([0.4412], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 65 is running
# LOSS: tensor([0.4436], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 66 is running
# LOSS: tensor([0.4401], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 67 is running
# LOSS: tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 68 is running
# LOSS: tensor([0.4427], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 69 is running
# LOSS: tensor([0.4463], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 70 is running
# LOSS: tensor([0.4414], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 71 is running
# LOSS: tensor([0.4461], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 72 is running
# LOSS: tensor([0.4439], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 73 is running
# LOSS: tensor([0.4464], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 74 is running
# LOSS: tensor([0.4426], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 75 is running
# LOSS: tensor([0.4479], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 76 is running
# LOSS: tensor([0.4453], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 77 is running
# LOSS: tensor([0.4487], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 78 is running
# LOSS: tensor([0.4446], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 79 is running
# LOSS: tensor([0.4475], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 80 is running
# LOSS: tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 81 is running
# LOSS: tensor([0.4496], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 82 is running
# LOSS: tensor([0.4449], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 83 is running
# LOSS: tensor([0.4502], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 84 is running
# LOSS: tensor([0.4438], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 85 is running
# LOSS: tensor([0.4486], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 86 is running
# LOSS: tensor([0.4445], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 87 is running
# LOSS: tensor([0.4507], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 88 is running
# LOSS: tensor([0.4454], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 89 is running
# LOSS: tensor([0.4491], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 90 is running
# LOSS: tensor([0.4463], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 91 is running
# LOSS: tensor([0.4486], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 92 is running
# LOSS: tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 93 is running
# LOSS: tensor([0.4518], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 94 is running
# LOSS: tensor([0.4464], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 95 is running
# LOSS: tensor([0.4503], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 96 is running
# LOSS: tensor([0.4471], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 97 is running
# LOSS: tensor([0.4520], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 98 is running
# LOSS: tensor([0.4468], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 99 is running
# LOSS: tensor([0.4503], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 100 is running
# LOSS: tensor([0.4473], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 101 is running
# LOSS: tensor([0.4528], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 102 is running
# LOSS: tensor([0.4497], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 103 is running
# LOSS: tensor([0.4513], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 104 is running
# LOSS: tensor([0.4468], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 105 is running
# LOSS: tensor([0.4531], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 106 is running
# LOSS: tensor([0.4489], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 107 is running
# LOSS: tensor([0.4524], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 108 is running
# LOSS: tensor([0.4471], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 109 is running
# LOSS: tensor([0.4528], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 110 is running
# LOSS: tensor([0.4495], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 111 is running
# LOSS: tensor([0.4538], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 112 is running
# LOSS: tensor([0.4483], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 113 is running
# LOSS: tensor([0.4535], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 114 is running
# LOSS: tensor([0.4473], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 115 is running
# LOSS: tensor([0.4548], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 116 is running
# LOSS: tensor([0.4516], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 117 is running
# LOSS: tensor([0.4539], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 118 is running
# LOSS: tensor([0.4493], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 119 is running
# LOSS: tensor([0.4546], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 120 is running
# LOSS: tensor([0.4500], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 121 is running
# LOSS: tensor([0.4528], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 122 is running
# LOSS: tensor([0.4476], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 123 is running
# LOSS: tensor([0.4543], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 124 is running
# LOSS: tensor([0.4527], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 125 is running
# LOSS: tensor([0.4557], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 126 is running
# LOSS: tensor([0.4523], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 127 is running
# LOSS: tensor([0.4556], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 128 is running
# LOSS: tensor([0.4518], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 129 is running
# LOSS: tensor([0.4546], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 130 is running
# LOSS: tensor([0.4503], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 131 is running
# LOSS: tensor([0.4560], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 132 is running
# LOSS: tensor([0.4516], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 133 is running
# LOSS: tensor([0.4562], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 134 is running
# LOSS: tensor([0.4491], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 135 is running
# LOSS: tensor([0.4545], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 136 is running
# LOSS: tensor([0.4539], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 137 is running
# LOSS: tensor([0.4543], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 138 is running
# LOSS: tensor([0.4529], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 139 is running
# LOSS: tensor([0.4576], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 140 is running
# LOSS: tensor([0.4520], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 141 is running
# LOSS: tensor([0.4566], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 142 is running
# LOSS: tensor([0.4540], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 143 is running
# LOSS: tensor([0.4538], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 144 is running
# LOSS: tensor([0.4519], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 145 is running
# LOSS: tensor([0.4547], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 146 is running
# LOSS: tensor([0.4522], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 147 is running
# LOSS: tensor([0.4566], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 148 is running
# LOSS: tensor([0.4511], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 149 is running
# LOSS: tensor([0.4570], device='cuda:0', grad_fn=<SumBackward1>)
# LOSSES: [-1000000000.0, tensor([-0.0371], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.0183], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.0699], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.1225], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.1546], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2005], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2222], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2497], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2551], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2826], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3019], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3040], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3159], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3337], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3363], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3536], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3525], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3661], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3637], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3810], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3751], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3866], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3835], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3941], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3928], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4004], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3967], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4089], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4073], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4095], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4105], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4153], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4140], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4192], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4187], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4239], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4214], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4254], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4230], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4295], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4259], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4314], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4273], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4317], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4289], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4321], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4369], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4325], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4359], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4334], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4398], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4351], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4397], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4376], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4402], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4375], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4419], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4380], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4424], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4396], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4429], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4379], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4412], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4436], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4401], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4451], devic ...
# 140
# tensor([0.4576], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 0 is running
# LOSS: tensor([-0.8329], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 1 is running
# LOSS: tensor([-0.6175], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 2 is running
# LOSS: tensor([-0.5218], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 3 is running
# LOSS: tensor([-0.4189], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 4 is running
# LOSS: tensor([-0.3335], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 5 is running
# LOSS: tensor([-0.2571], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 6 is running
# LOSS: tensor([-0.1969], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 7 is running
# LOSS: -1000000000.0
# Iteration 8 is running
# LOSS: -1000000000.0
# Iteration 9 is running
# LOSS: -1000000000.0
# Iteration 10 is running
# LOSS: -1000000000.0
# Iteration 11 is running
# LOSS: -1000000000.0
# Iteration 12 is running
# LOSS: -1000000000.0
# Iteration 13 is running
# LOSS: -1000000000.0
# Iteration 14 is running
# LOSS: -1000000000.0
# Iteration 15 is running
# LOSS: -1000000000.0
# Iteration 16 is running
# LOSS: -1000000000.0
# Iteration 17 is running
# LOSS: -1000000000.0
# Iteration 18 is running
# LOSS: -1000000000.0
# Iteration 19 is running
# LOSS: -1000000000.0
# Iteration 20 is running
# LOSS: -1000000000.0
# Iteration 21 is running
# LOSS: -1000000000.0
# Iteration 22 is running
# LOSS: -1000000000.0
# Iteration 23 is running
# LOSS: -1000000000.0
# Iteration 24 is running
# LOSS: -1000000000.0
# Iteration 25 is running
# LOSS: -1000000000.0
# Iteration 26 is running
# LOSS: -1000000000.0
# Iteration 27 is running
# LOSS: -1000000000.0
# Iteration 28 is running
# LOSS: -1000000000.0
# Iteration 29 is running
# LOSS: -1000000000.0
# Iteration 30 is running
# LOSS: -1000000000.0
# Iteration 31 is running
# LOSS: -1000000000.0
# Iteration 32 is running
# LOSS: -1000000000.0
# Iteration 33 is running
# LOSS: -1000000000.0
# Iteration 34 is running
# LOSS: -1000000000.0
# Iteration 35 is running
# LOSS: -1000000000.0
# Iteration 36 is running
# LOSS: -1000000000.0
# Iteration 37 is running
# LOSS: -1000000000.0
# Iteration 38 is running
# LOSS: -1000000000.0
# Iteration 39 is running
# LOSS: -1000000000.0
# Iteration 40 is running
# LOSS: -1000000000.0
# Iteration 41 is running
# LOSS: -1000000000.0
# Iteration 42 is running
# LOSS: -1000000000.0
# Iteration 43 is running
# LOSS: -1000000000.0
# Iteration 44 is running
# LOSS: -1000000000.0
# Iteration 45 is running
# LOSS: -1000000000.0
# Iteration 46 is running
# LOSS: -1000000000.0
# Iteration 47 is running
# LOSS: -1000000000.0
# Iteration 48 is running
# LOSS: -1000000000.0
# Iteration 49 is running
# LOSS: -1000000000.0
# Iteration 50 is running
# LOSS: -1000000000.0
# Iteration 51 is running
# LOSS: tensor([0.1488], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 52 is running
# LOSS: -1000000000.0
# Iteration 53 is running
# LOSS: tensor([0.1490], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 54 is running
# LOSS: -1000000000.0
# Iteration 55 is running
# LOSS: tensor([0.1494], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 56 is running
# LOSS: -1000000000.0
# Iteration 57 is running
# LOSS: tensor([0.1501], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 58 is running
# LOSS: -1000000000.0
# Iteration 59 is running
# LOSS: tensor([0.1509], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 60 is running
# LOSS: -1000000000.0
# Iteration 61 is running
# LOSS: tensor([0.1519], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 62 is running
# LOSS: -1000000000.0
# Iteration 63 is running
# LOSS: tensor([0.1509], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 64 is running
# LOSS: -1000000000.0
# Iteration 65 is running
# LOSS: tensor([0.1535], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 66 is running
# LOSS: -1000000000.0
# Iteration 67 is running
# LOSS: tensor([0.1537], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 68 is running
# LOSS: -1000000000.0
# Iteration 69 is running
# LOSS: tensor([0.1541], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 70 is running
# LOSS: -1000000000.0
# Iteration 71 is running
# LOSS: tensor([0.1536], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 72 is running
# LOSS: -1000000000.0
# Iteration 73 is running
# LOSS: tensor([0.1538], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 74 is running
# LOSS: -1000000000.0
# Iteration 75 is running
# LOSS: tensor([0.1546], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 76 is running
# LOSS: -1000000000.0
# Iteration 77 is running
# LOSS: tensor([0.1557], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 78 is running
# LOSS: -1000000000.0
# Iteration 79 is running
# LOSS: tensor([0.1562], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 80 is running
# LOSS: -1000000000.0
# Iteration 81 is running
# LOSS: tensor([0.1552], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 82 is running
# LOSS: -1000000000.0
# Iteration 83 is running
# LOSS: tensor([0.1573], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 84 is running
# LOSS: -1000000000.0
# Iteration 85 is running
# LOSS: tensor([0.1547], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 86 is running
# LOSS: -1000000000.0
# Iteration 87 is running
# LOSS: tensor([0.1558], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 88 is running
# LOSS: -1000000000.0
# Iteration 89 is running
# LOSS: tensor([0.1543], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 90 is running
# LOSS: -1000000000.0
# Iteration 91 is running
# LOSS: tensor([0.1575], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 92 is running
# LOSS: -1000000000.0
# Iteration 93 is running
# LOSS: tensor([0.1578], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 94 is running
# LOSS: -1000000000.0
# Iteration 95 is running
# LOSS: tensor([0.1593], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 96 is running
# LOSS: -1000000000.0
# Iteration 97 is running
# LOSS: tensor([0.1592], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 98 is running
# LOSS: -1000000000.0
# Iteration 99 is running
# LOSS: tensor([0.1575], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 100 is running
# LOSS: -1000000000.0
# Iteration 101 is running
# LOSS: tensor([0.1567], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 102 is running
# LOSS: -1000000000.0
# Iteration 103 is running
# LOSS: tensor([0.1599], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 104 is running
# LOSS: -1000000000.0
# Iteration 105 is running
# LOSS: tensor([0.1579], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 106 is running
# LOSS: -1000000000.0
# Iteration 107 is running
# LOSS: tensor([0.1595], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 108 is running
# LOSS: -1000000000.0
# Iteration 109 is running
# LOSS: tensor([0.1620], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 110 is running
# LOSS: -1000000000.0
# Iteration 111 is running
# LOSS: tensor([0.1627], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 112 is running
# LOSS: -1000000000.0
# Iteration 113 is running
# LOSS: tensor([0.1626], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 114 is running
# LOSS: -1000000000.0
# Iteration 115 is running
# LOSS: tensor([0.1598], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 116 is running
# LOSS: -1000000000.0
# Iteration 117 is running
# LOSS: tensor([0.1595], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 118 is running
# LOSS: -1000000000.0
# Iteration 119 is running
# LOSS: tensor([0.1617], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 120 is running
# LOSS: -1000000000.0
# Iteration 121 is running
# LOSS: tensor([0.1631], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 122 is running
# LOSS: -1000000000.0
# Iteration 123 is running
# LOSS: tensor([0.1618], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 124 is running
# LOSS: -1000000000.0
# Iteration 125 is running
# LOSS: tensor([0.1622], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 126 is running
# LOSS: -1000000000.0
# Iteration 127 is running
# LOSS: tensor([0.1612], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 128 is running
# LOSS: -1000000000.0
# Iteration 129 is running
# LOSS: tensor([0.1608], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 130 is running
# LOSS: -1000000000.0
# Iteration 131 is running
# LOSS: tensor([0.1603], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 132 is running
# LOSS: -1000000000.0
# Iteration 133 is running
# LOSS: tensor([0.1629], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 134 is running
# LOSS: -1000000000.0
# Iteration 135 is running
# LOSS: tensor([0.1624], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 136 is running
# LOSS: -1000000000.0
# Iteration 137 is running
# LOSS: tensor([0.1649], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 138 is running
# LOSS: -1000000000.0
# Iteration 139 is running
# LOSS: tensor([0.1637], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 140 is running
# LOSS: -1000000000.0
# Iteration 141 is running
# LOSS: tensor([0.1635], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 142 is running
# LOSS: -1000000000.0
# Iteration 143 is running
# LOSS: tensor([0.1635], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 144 is running
# LOSS: -1000000000.0
# Iteration 145 is running
# LOSS: tensor([0.1640], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 146 is running
# LOSS: -1000000000.0
# Iteration 147 is running
# LOSS: tensor([0.1647], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 148 is running
# LOSS: -1000000000.0
# Iteration 149 is running
# LOSS: tensor([0.1637], device='cuda:0', grad_fn=<NegBackward0>)
# LOSSES: [-1000000000.0, tensor([-0.8329], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.6175], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.5218], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.4189], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.3335], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.2571], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.1969], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, -1000000000.0, tensor([0.1488], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1490], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1494], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1501], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1509], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1519], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1509], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1535], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1537], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1541], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1536], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1538], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1546], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1557], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1562], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1552], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1573], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1547], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1558], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1543], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1575], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1578], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1593], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1592], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1575], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1567], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1599], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1579], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1595], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1620], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1627], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1626], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1598], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1595], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1617], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1631], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1618], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1622], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1612], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0. ...
# 138
# tensor([0.1649], device='cuda:0', grad_fn=<NegBackward0>)

# %%
real_y_pred = torch.argmax(cnn.forward(X.unsqueeze(0)))
manipulated_y_pred_1 = torch.argmax(cnn.forward(X_p_g_1))
manipulated_y_pred_2 = torch.argmax(cnn.forward(X_p_g_2))

print("ORIGIN PRED:", animals_dict[real_y_pred.item()])
print("RANDOM ATTACKED PRED:", animals_dict[manipulated_y_pred_1.item()])
print("TARGET ATTACKED PRED:", animals_dict[manipulated_y_pred_2.item()])
# Out:
# ORIGIN PRED: squirrel
# RANDOM ATTACKED PRED: squirrel
# TARGET ATTACKED PRED: squirrel

# %%
origin_img = X.permute([1,2,0]).detach().to('cpu')
manipulated_img_1 = X_p_g_1.squeeze().permute([1,2,0]).detach().to('cpu')
manipulated_img_2 = X_p_g_2.squeeze().permute([1,2,0]).detach().to('cpu')

g_real_saliency = g.explain(X,real_y_pred).squeeze().detach().to('cpu')
g_manipulated_saliency_1 = g.explain(X_p_g_1,real_y_pred, model = cnn).squeeze().detach().to('cpu')
g_manipulated_saliency_2 = g.explain(X_p_g_2,real_y_pred, model = cnn).squeeze().detach().to('cpu')


print()
# Out:
# <ipython-input-5-acc1a5bc07ab>:16: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_pred = F.softmax(model.forward(img))

# %%
fig, axs = plt.subplots(3, 2, figsize=(9, 13))

axs[0, 0].imshow(origin_img, cmap = 'hot')
axs[0, 0].set_title('Origin Image')
axs[0, 1].imshow(g_real_saliency, cmap = 'hot')
axs[0, 1].set_title('Origin Image Explanation')
axs[1, 0].imshow(manipulated_img_1, cmap = 'hot')
axs[1, 0].set_title('Manipulated Image (Target)')
axs[1, 1].imshow(g_manipulated_saliency_1, cmap = 'hot')
axs[1, 1].set_title('Manipulated Image (Target) Explanation')
axs[2, 0].imshow(manipulated_img_2, cmap = 'hot')
axs[2, 0].set_title('Manipulated Image (Random)')
axs[2, 1].imshow(g_manipulated_saliency_2, cmap = 'hot')
axs[2, 1].set_title('Manipulated Image (Random) Explanation')

plt.show()

# %%
X_p_ig_1 = attacker.iterative_attack(X, model = cnn, model_p=cnn_p, explainer=ig, num_steps = 150, alpha = 0.0025, epsilon=0.03, mode = 'target', target = target)
X_p_ig_2 = attacker.iterative_attack(X, model = cnn, model_p=cnn_p, explainer=ig, num_steps = 150, alpha = 0.0025, epsilon=0.03, mode = 'random')
# Out:
# Iteration 0 is running
# <ipython-input-6-dc0c176f639a>:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_pred = F.softmax(model.forward(x_ig))
# LOSS: tensor([0.0819], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 1 is running
# LOSS: tensor([0.1361], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 2 is running
# LOSS: tensor([0.1833], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 3 is running
# LOSS: tensor([0.2210], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 4 is running
# LOSS: tensor([0.2544], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 5 is running
# LOSS: tensor([0.2851], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 6 is running
# LOSS: tensor([0.3106], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 7 is running
# LOSS: tensor([0.3324], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 8 is running
# LOSS: tensor([0.3495], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 9 is running
# LOSS: tensor([0.3612], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 10 is running
# LOSS: tensor([0.3717], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 11 is running
# LOSS: tensor([0.3808], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 12 is running
# LOSS: tensor([0.3883], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 13 is running
# LOSS: tensor([0.3933], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 14 is running
# LOSS: tensor([0.3898], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 15 is running
# LOSS: tensor([0.3966], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 16 is running
# LOSS: tensor([0.4014], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 17 is running
# LOSS: tensor([0.4041], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 18 is running
# LOSS: tensor([0.4082], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 19 is running
# LOSS: tensor([0.4104], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 20 is running
# LOSS: tensor([0.4116], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 21 is running
# LOSS: tensor([0.4136], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 22 is running
# LOSS: tensor([0.4139], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 23 is running
# LOSS: tensor([0.4183], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 24 is running
# LOSS: tensor([0.4214], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 25 is running
# LOSS: tensor([0.4224], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 26 is running
# LOSS: tensor([0.4212], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 27 is running
# LOSS: tensor([0.4291], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 28 is running
# LOSS: tensor([0.4290], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 29 is running
# LOSS: tensor([0.4288], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 30 is running
# LOSS: tensor([0.4301], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 31 is running
# LOSS: tensor([0.4309], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 32 is running
# LOSS: tensor([0.4317], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 33 is running
# LOSS: tensor([0.4360], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 34 is running
# LOSS: tensor([0.4326], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 35 is running
# LOSS: tensor([0.4321], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 36 is running
# LOSS: tensor([0.4340], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 37 is running
# LOSS: tensor([0.4351], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 38 is running
# LOSS: tensor([0.4330], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 39 is running
# LOSS: tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 40 is running
# LOSS: tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 41 is running
# LOSS: tensor([0.4365], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 42 is running
# LOSS: tensor([0.4365], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 43 is running
# LOSS: tensor([0.4391], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 44 is running
# LOSS: tensor([0.4378], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 45 is running
# LOSS: tensor([0.4387], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 46 is running
# LOSS: tensor([0.4396], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 47 is running
# LOSS: tensor([0.4435], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 48 is running
# LOSS: tensor([0.4394], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 49 is running
# LOSS: tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 50 is running
# LOSS: tensor([0.4431], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 51 is running
# LOSS: tensor([0.4436], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 52 is running
# LOSS: tensor([0.4411], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 53 is running
# LOSS: tensor([0.4429], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 54 is running
# LOSS: tensor([0.4404], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 55 is running
# LOSS: tensor([0.4431], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 56 is running
# LOSS: tensor([0.4421], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 57 is running
# LOSS: tensor([0.4415], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 58 is running
# LOSS: tensor([0.4413], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 59 is running
# LOSS: tensor([0.4440], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 60 is running
# LOSS: tensor([0.4445], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 61 is running
# LOSS: tensor([0.4432], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 62 is running
# LOSS: tensor([0.4411], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 63 is running
# LOSS: tensor([0.4454], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 64 is running
# LOSS: tensor([0.4410], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 65 is running
# LOSS: tensor([0.4433], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 66 is running
# LOSS: tensor([0.4412], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 67 is running
# LOSS: tensor([0.4435], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 68 is running
# LOSS: tensor([0.4413], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 69 is running
# LOSS: tensor([0.4427], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 70 is running
# LOSS: tensor([0.4406], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 71 is running
# LOSS: tensor([0.4449], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 72 is running
# LOSS: tensor([0.4445], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 73 is running
# LOSS: tensor([0.4467], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 74 is running
# LOSS: tensor([0.4418], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 75 is running
# LOSS: tensor([0.4460], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 76 is running
# LOSS: tensor([0.4433], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 77 is running
# LOSS: tensor([0.4469], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 78 is running
# LOSS: tensor([0.4457], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 79 is running
# LOSS: tensor([0.4472], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 80 is running
# LOSS: tensor([0.4452], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 81 is running
# LOSS: tensor([0.4444], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 82 is running
# LOSS: tensor([0.4456], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 83 is running
# LOSS: tensor([0.4475], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 84 is running
# LOSS: tensor([0.4449], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 85 is running
# LOSS: tensor([0.4467], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 86 is running
# LOSS: tensor([0.4430], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 87 is running
# LOSS: tensor([0.4456], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 88 is running
# LOSS: tensor([0.4446], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 89 is running
# LOSS: tensor([0.4482], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 90 is running
# LOSS: tensor([0.4459], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 91 is running
# LOSS: tensor([0.4484], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 92 is running
# LOSS: tensor([0.4445], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 93 is running
# LOSS: tensor([0.4497], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 94 is running
# LOSS: tensor([0.4464], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 95 is running
# LOSS: tensor([0.4514], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 96 is running
# LOSS: tensor([0.4467], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 97 is running
# LOSS: tensor([0.4494], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 98 is running
# LOSS: tensor([0.4440], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 99 is running
# LOSS: tensor([0.4501], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 100 is running
# LOSS: tensor([0.4408], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 101 is running
# LOSS: tensor([0.4478], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 102 is running
# LOSS: tensor([0.4466], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 103 is running
# LOSS: tensor([0.4500], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 104 is running
# LOSS: tensor([0.4458], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 105 is running
# LOSS: tensor([0.4479], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 106 is running
# LOSS: tensor([0.4456], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 107 is running
# LOSS: tensor([0.4493], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 108 is running
# LOSS: tensor([0.4467], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 109 is running
# LOSS: tensor([0.4512], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 110 is running
# LOSS: tensor([0.4471], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 111 is running
# LOSS: tensor([0.4505], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 112 is running
# LOSS: tensor([0.4454], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 113 is running
# LOSS: tensor([0.4484], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 114 is running
# LOSS: tensor([0.4438], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 115 is running
# LOSS: tensor([0.4508], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 116 is running
# LOSS: tensor([0.4501], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 117 is running
# LOSS: tensor([0.4506], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 118 is running
# LOSS: tensor([0.4480], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 119 is running
# LOSS: tensor([0.4503], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 120 is running
# LOSS: tensor([0.4483], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 121 is running
# LOSS: tensor([0.4486], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 122 is running
# LOSS: tensor([0.4452], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 123 is running
# LOSS: tensor([0.4477], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 124 is running
# LOSS: tensor([0.4489], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 125 is running
# LOSS: tensor([0.4510], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 126 is running
# LOSS: tensor([0.4506], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 127 is running
# LOSS: tensor([0.4526], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 128 is running
# LOSS: tensor([0.4472], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 129 is running
# LOSS: tensor([0.4484], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 130 is running
# LOSS: tensor([0.4489], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 131 is running
# LOSS: tensor([0.4517], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 132 is running
# LOSS: tensor([0.4514], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 133 is running
# LOSS: tensor([0.4520], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 134 is running
# LOSS: tensor([0.4499], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 135 is running
# LOSS: tensor([0.4517], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 136 is running
# LOSS: tensor([0.4482], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 137 is running
# LOSS: tensor([0.4483], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 138 is running
# LOSS: tensor([0.4498], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 139 is running
# LOSS: tensor([0.4527], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 140 is running
# LOSS: tensor([0.4514], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 141 is running
# LOSS: tensor([0.4525], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 142 is running
# LOSS: tensor([0.4497], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 143 is running
# LOSS: tensor([0.4507], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 144 is running
# LOSS: tensor([0.4531], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 145 is running
# LOSS: tensor([0.4543], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 146 is running
# LOSS: tensor([0.4525], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 147 is running
# LOSS: tensor([0.4524], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 148 is running
# LOSS: tensor([0.4508], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 149 is running
# LOSS: tensor([0.4522], device='cuda:0', grad_fn=<SumBackward1>)
# LOSSES: [-1000000000.0, tensor([0.0819], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.1361], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.1833], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2210], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2544], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.2851], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3106], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3324], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3495], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3612], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3717], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3808], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3883], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3933], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3898], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.3966], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4014], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4041], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4082], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4104], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4116], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4136], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4139], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4183], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4214], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4224], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4212], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4291], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4290], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4288], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4301], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4309], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4317], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4360], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4326], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4321], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4340], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4351], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4330], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4368], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4365], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4365], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4391], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4378], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4387], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4396], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4435], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4394], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4451], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4431], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4436], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4411], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4429], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4404], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4431], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4421], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4415], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4413], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4440], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4445], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4432], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4411], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4454], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4410], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4433], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4412], device='cuda:0', grad_fn=<SumBackward1>), tensor([0.4435], device ...
# 146
# tensor([0.4543], device='cuda:0', grad_fn=<SumBackward1>)
# Iteration 0 is running
# LOSS: tensor([-0.7926], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 1 is running
# LOSS: tensor([-0.6585], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 2 is running
# LOSS: -1000000000.0
# Iteration 3 is running
# LOSS: tensor([-0.4007], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 4 is running
# LOSS: -1000000000.0
# Iteration 5 is running
# LOSS: tensor([-0.2905], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 6 is running
# LOSS: -1000000000.0
# Iteration 7 is running
# LOSS: tensor([-0.1689], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 8 is running
# LOSS: -1000000000.0
# Iteration 9 is running
# LOSS: tensor([-0.1039], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 10 is running
# LOSS: -1000000000.0
# Iteration 11 is running
# LOSS: tensor([-0.0620], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 12 is running
# LOSS: -1000000000.0
# Iteration 13 is running
# LOSS: tensor([-0.0372], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 14 is running
# LOSS: -1000000000.0
# Iteration 15 is running
# LOSS: tensor([-0.0222], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 16 is running
# LOSS: -1000000000.0
# Iteration 17 is running
# LOSS: tensor([-0.0110], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 18 is running
# LOSS: -1000000000.0
# Iteration 19 is running
# LOSS: tensor([0.0046], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 20 is running
# LOSS: -1000000000.0
# Iteration 21 is running
# LOSS: tensor([0.0141], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 22 is running
# LOSS: -1000000000.0
# Iteration 23 is running
# LOSS: tensor([0.0239], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 24 is running
# LOSS: -1000000000.0
# Iteration 25 is running
# LOSS: tensor([0.0344], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 26 is running
# LOSS: -1000000000.0
# Iteration 27 is running
# LOSS: tensor([0.0403], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 28 is running
# LOSS: -1000000000.0
# Iteration 29 is running
# LOSS: tensor([0.0463], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 30 is running
# LOSS: -1000000000.0
# Iteration 31 is running
# LOSS: tensor([0.0508], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 32 is running
# LOSS: -1000000000.0
# Iteration 33 is running
# LOSS: tensor([0.0563], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 34 is running
# LOSS: -1000000000.0
# Iteration 35 is running
# LOSS: tensor([0.0612], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 36 is running
# LOSS: -1000000000.0
# Iteration 37 is running
# LOSS: tensor([0.0645], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 38 is running
# LOSS: -1000000000.0
# Iteration 39 is running
# LOSS: tensor([0.0676], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 40 is running
# LOSS: -1000000000.0
# Iteration 41 is running
# LOSS: tensor([0.0702], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 42 is running
# LOSS: -1000000000.0
# Iteration 43 is running
# LOSS: tensor([0.0725], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 44 is running
# LOSS: -1000000000.0
# Iteration 45 is running
# LOSS: tensor([0.0730], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 46 is running
# LOSS: -1000000000.0
# Iteration 47 is running
# LOSS: tensor([0.0752], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 48 is running
# LOSS: -1000000000.0
# Iteration 49 is running
# LOSS: tensor([0.0786], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 50 is running
# LOSS: -1000000000.0
# Iteration 51 is running
# LOSS: tensor([0.0792], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 52 is running
# LOSS: -1000000000.0
# Iteration 53 is running
# LOSS: tensor([0.0807], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 54 is running
# LOSS: -1000000000.0
# Iteration 55 is running
# LOSS: tensor([0.0815], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 56 is running
# LOSS: -1000000000.0
# Iteration 57 is running
# LOSS: tensor([0.0829], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 58 is running
# LOSS: -1000000000.0
# Iteration 59 is running
# LOSS: tensor([0.0836], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 60 is running
# LOSS: -1000000000.0
# Iteration 61 is running
# LOSS: tensor([0.0872], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 62 is running
# LOSS: -1000000000.0
# Iteration 63 is running
# LOSS: tensor([0.0906], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 64 is running
# LOSS: -1000000000.0
# Iteration 65 is running
# LOSS: tensor([0.0922], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 66 is running
# LOSS: -1000000000.0
# Iteration 67 is running
# LOSS: tensor([0.0954], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 68 is running
# LOSS: -1000000000.0
# Iteration 69 is running
# LOSS: tensor([0.0966], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 70 is running
# LOSS: -1000000000.0
# Iteration 71 is running
# LOSS: tensor([0.1001], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 72 is running
# LOSS: -1000000000.0
# Iteration 73 is running
# LOSS: tensor([0.1025], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 74 is running
# LOSS: -1000000000.0
# Iteration 75 is running
# LOSS: tensor([0.1022], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 76 is running
# LOSS: -1000000000.0
# Iteration 77 is running
# LOSS: tensor([0.1024], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 78 is running
# LOSS: -1000000000.0
# Iteration 79 is running
# LOSS: tensor([0.1046], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 80 is running
# LOSS: -1000000000.0
# Iteration 81 is running
# LOSS: tensor([0.1059], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 82 is running
# LOSS: -1000000000.0
# Iteration 83 is running
# LOSS: tensor([0.1066], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 84 is running
# LOSS: -1000000000.0
# Iteration 85 is running
# LOSS: tensor([0.1072], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 86 is running
# LOSS: -1000000000.0
# Iteration 87 is running
# LOSS: tensor([0.1080], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 88 is running
# LOSS: -1000000000.0
# Iteration 89 is running
# LOSS: tensor([0.1091], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 90 is running
# LOSS: -1000000000.0
# Iteration 91 is running
# LOSS: tensor([0.1092], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 92 is running
# LOSS: -1000000000.0
# Iteration 93 is running
# LOSS: tensor([0.1092], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 94 is running
# LOSS: -1000000000.0
# Iteration 95 is running
# LOSS: tensor([0.1089], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 96 is running
# LOSS: -1000000000.0
# Iteration 97 is running
# LOSS: tensor([0.1106], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 98 is running
# LOSS: -1000000000.0
# Iteration 99 is running
# LOSS: tensor([0.1102], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 100 is running
# LOSS: -1000000000.0
# Iteration 101 is running
# LOSS: tensor([0.1113], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 102 is running
# LOSS: -1000000000.0
# Iteration 103 is running
# LOSS: tensor([0.1111], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 104 is running
# LOSS: -1000000000.0
# Iteration 105 is running
# LOSS: tensor([0.1114], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 106 is running
# LOSS: -1000000000.0
# Iteration 107 is running
# LOSS: tensor([0.1107], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 108 is running
# LOSS: -1000000000.0
# Iteration 109 is running
# LOSS: tensor([0.1127], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 110 is running
# LOSS: -1000000000.0
# Iteration 111 is running
# LOSS: tensor([0.1122], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 112 is running
# LOSS: -1000000000.0
# Iteration 113 is running
# LOSS: tensor([0.1114], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 114 is running
# LOSS: -1000000000.0
# Iteration 115 is running
# LOSS: tensor([0.1123], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 116 is running
# LOSS: -1000000000.0
# Iteration 117 is running
# LOSS: tensor([0.1124], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 118 is running
# LOSS: -1000000000.0
# Iteration 119 is running
# LOSS: tensor([0.1123], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 120 is running
# LOSS: -1000000000.0
# Iteration 121 is running
# LOSS: tensor([0.1124], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 122 is running
# LOSS: -1000000000.0
# Iteration 123 is running
# LOSS: tensor([0.1131], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 124 is running
# LOSS: -1000000000.0
# Iteration 125 is running
# LOSS: tensor([0.1144], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 126 is running
# LOSS: -1000000000.0
# Iteration 127 is running
# LOSS: tensor([0.1144], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 128 is running
# LOSS: -1000000000.0
# Iteration 129 is running
# LOSS: tensor([0.1148], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 130 is running
# LOSS: -1000000000.0
# Iteration 131 is running
# LOSS: tensor([0.1153], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 132 is running
# LOSS: -1000000000.0
# Iteration 133 is running
# LOSS: tensor([0.1156], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 134 is running
# LOSS: -1000000000.0
# Iteration 135 is running
# LOSS: tensor([0.1145], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 136 is running
# LOSS: -1000000000.0
# Iteration 137 is running
# LOSS: tensor([0.1146], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 138 is running
# LOSS: -1000000000.0
# Iteration 139 is running
# LOSS: tensor([0.1148], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 140 is running
# LOSS: -1000000000.0
# Iteration 141 is running
# LOSS: tensor([0.1153], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 142 is running
# LOSS: -1000000000.0
# Iteration 143 is running
# LOSS: tensor([0.1161], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 144 is running
# LOSS: -1000000000.0
# Iteration 145 is running
# LOSS: tensor([0.1153], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 146 is running
# LOSS: -1000000000.0
# Iteration 147 is running
# LOSS: tensor([0.1164], device='cuda:0', grad_fn=<NegBackward0>)
# Iteration 148 is running
# LOSS: -1000000000.0
# Iteration 149 is running
# LOSS: tensor([0.1154], device='cuda:0', grad_fn=<NegBackward0>)
# LOSSES: [-1000000000.0, tensor([-0.7926], device='cuda:0', grad_fn=<NegBackward0>), tensor([-0.6585], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.4007], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.2905], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.1689], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.1039], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.0620], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.0372], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.0222], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([-0.0110], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0046], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0141], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0239], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0344], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0403], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0463], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0508], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0563], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0612], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0645], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0676], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0702], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0725], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0730], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0752], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0786], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0792], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0807], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0815], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0829], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0836], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0872], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0906], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0922], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0954], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.0966], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1001], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1025], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1022], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1024], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1046], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1059], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1066], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1072], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1080], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1091], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1092], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1092], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1089], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1106], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1102], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1113], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1111], device='cuda:0', grad_fn=<NegBackward0>), -1000000000.0, tensor([0.1114], device='cuda:0', grad_fn=<NegBackward0>),  ...
# 148
# tensor([0.1164], device='cuda:0', grad_fn=<NegBackward0>)

# %%
real_y_pred = torch.argmax(cnn.forward(X.unsqueeze(0)))
manipulated_y_pred_1 = torch.argmax(cnn.forward(X_p_ig_1))
manipulated_y_pred_2 = torch.argmax(cnn.forward(X_p_ig_2))

print("ORIGIN PRED:", animals_dict[real_y_pred.item()])
print("RANDOM ATTACKED PRED:", animals_dict[manipulated_y_pred_1.item()])
print("TARGET ATTACKED PRED:", animals_dict[manipulated_y_pred_2.item()])
# Out:
# ORIGIN PRED: squirrel
# RANDOM ATTACKED PRED: squirrel
# TARGET ATTACKED PRED: squirrel

# %%
origin_img = X.permute([1,2,0]).detach().to('cpu')
manipulated_img_1 = X_p_ig_1.squeeze().permute([1,2,0]).detach().to('cpu')
manipulated_img_2 = X_p_ig_2.squeeze().permute([1,2,0]).detach().to('cpu')

g_real_saliency = ig.explain(X,real_y_pred).squeeze().detach().to('cpu')
g_manipulated_saliency_1 = ig.explain(X_p_ig_1,real_y_pred, model = cnn).squeeze().detach().to('cpu')
g_manipulated_saliency_2 = ig.explain(X_p_ig_2,real_y_pred, model = cnn).squeeze().detach().to('cpu')


print()
# Out:
# <ipython-input-6-dc0c176f639a>:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y_pred = F.softmax(model.forward(x_ig))

# %%
fig, axs = plt.subplots(3, 2, figsize=(9, 13))

axs[0, 0].imshow(origin_img, cmap = 'hot')
axs[0, 0].set_title('Origin Image')
axs[0, 1].imshow(g_real_saliency, cmap = 'hot')
axs[0, 1].set_title('Origin Image Explanation')
axs[1, 0].imshow(manipulated_img_1, cmap = 'hot')
axs[1, 0].set_title('Manipulated Image (Target)')
axs[1, 1].imshow(g_manipulated_saliency_1, cmap = 'hot')
axs[1, 1].set_title('Manipulated Image (Target) Explanation')
axs[2, 0].imshow(manipulated_img_2, cmap = 'hot')
axs[2, 0].set_title('Manipulated Image (Random)')
axs[2, 1].imshow(g_manipulated_saliency_2, cmap = 'hot')
axs[2, 1].set_title('Manipulated Image (Random) Explanation')

plt.show()
